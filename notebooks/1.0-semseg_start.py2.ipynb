# %% [markdown]
# # semseg

# %% [markdown]
# Description: 2D semantic segmentation (Vaihingen dataset)

# %%
import socket
print(socket.gethostname())

# %%
import sys
sys.path.append('../semseg')

import matplotlib.pyplot as plt
# %matplotlib inline
